# %%
#Importamos Librerias
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Cargamos archivo
df= pd.read_csv('RiodeJaneiro.csv') 
df.head(10)
# Out:
# /var/folders/s5/9tn200911wjfzyc3b8q58s900000gn/T/ipykernel_1557/3363308871.py:2: DtypeWarning: Columns (0,2,9,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('RiodeJaneiro.csv')
#                      id                                      listing_url  \
# 0            53344884.0            https://www.airbnb.com/rooms/53344884
# 1             7801456.0             https://www.airbnb.com/rooms/7801456
# 2            14333905.0            https://www.airbnb.com/rooms/14333905
# 3            44708736.0            https://www.airbnb.com/rooms/44708736
# 4            35351763.0            https://www.airbnb.com/rooms/35351763
# 5            53042498.0            https://www.airbnb.com/rooms/53042498
# 6            48227858.0            https://www.airbnb.com/rooms/48227858
# 7  699000000000000000.0  https://www.airbnb.com/rooms/699421066162239071
# 8            47879942.0            https://www.airbnb.com/rooms/47879942
# ...

# %%
#Seleccionamos solo las columnas que utilizaremos para este análisis y crearemos un nuevo dataframe
df2 = df.loc[:, ['source','name', 'host_id','host_response_time','host_response_rate','host_acceptance_rate',
'host_is_superhost','host_listings_count','host_total_listings_count','host_identity_verified', 'neighbourhood',
'neighbourhood_cleansed','latitude','longitude','property_type','room_type','accommodates', 'bathrooms_text', 'bedrooms',
'beds', 'Ame2','Ame3','Ame4','Ame5', 'price', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'number_of_reviews_lastyear', 
'number_of_reviews_last30', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin',
'review_scores_communication', 'review_scores_location', 'review_scores_value', 'instant_bookable', 'calculated_host_listings_count', 
'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms']]
df2
# Out:
#             source                                              name  \
# 0      city scrape        Suntuoso apartamento em Copacabana posto 6
# 1      city scrape                Ipanema Vieira Souto - Linda Vista
# 2      city scrape                                Casa compartilhada
# 3      city scrape               Aluguel de Lancha no Rio de Janeiro
# 4      city scrape                                Uma grande família
# ...            ...                                               ...
# 26368  city scrape    Quarto mobiliado aconchegante em Copacabana/RJ
# 26369  city scrape   Small 1 bed aprt with panoramic roof top access
# 26370  city scrape                     Apartamento RJ perto da praia
# 26371  city scrape  Loft encantador de frente pra praia - Copacabana
# 26372  city scrape                                  Casa da Floresta
#
#          host_id  host_response_time host_response_rate host_acceptance_rate  \
# ...

# %%
#Detectamos valores nulos
valores_nulos = df2.isnull().sum()
valores_nulos

#Vemos los tipos de datos que tenemos en nuestro df
df2.dtypes
# Out:
# source                                           object
# name                                             object
# host_id                                          object
# host_response_time                               object
# host_response_rate                               object
# host_acceptance_rate                             object
# host_is_superhost                                object
# host_listings_count                             float64
# host_total_listings_count                       float64
# host_identity_verified                           object
# neighbourhood                                    object
# neighbourhood_cleansed                           object
# latitude                                        float64
# longitude                                       float64
# property_type                                    object
# room_type                                        object
# accommodates                                    float64
# ...

# %%
#Copia del dataframe
df3=df2.copy()

#Sutituimos valores nulos con "desconocido" para columnas de tipo "string"
df3=df3.iloc[ : , [0,1,3, 10,11,14,15,20]]
df3.fillna("desconocido") 

#Sustituir valores nulos con promedio 
df3["host_response_time"]=df3["host_response_time"].fillna(round(df2["host_response_time"].mean(),1))
df3["host_response_rate"]=df3["host_response_rate"].fillna(round(df2["host_response_rate"].mean(),1))
df3["host_acceptance_rate"]=df3["host_acceptance_rate"].fillna(round(df2["host_acceptance_rate"].mean(),1))
df3["host_listings_count"]=df3["host_listings_count"].fillna(round(df2["host_listings_count"].mean(),1))
df3["host_total_listings_count "]=df3["host_total_listings_count "].fillna(round(df2["host_total_listings_count "].mean(),1))
df3[""]=df3[""].fillna(round(df2[""].mean(),1))
df3[""]=df3[""].fillna(round(df2[""].mean(),1))
df3[""]=df3[""].fillna(round(df2[""].mean(),1))

df3
# Out:
#             source                                              name  \
# 0      city scrape        Suntuoso apartamento em Copacabana posto 6
# 1      city scrape                Ipanema Vieira Souto - Linda Vista
# 2      city scrape                                Casa compartilhada
# 3      city scrape               Aluguel de Lancha no Rio de Janeiro
# 4      city scrape                                Uma grande família
# ...            ...                                               ...
# 26367  city scrape    Quarto mobiliado aconchegante em Copacabana/RJ
# 26368  city scrape   Small 1 bed aprt with panoramic roof top access
# 26369  city scrape                     Apartamento RJ perto da praia
# 26370  city scrape  Loft encantador de frente pra praia - Copacabana
# 26371  city scrape                                  Casa da Floresta
#
#                                     neighbourhood    neighbourhood_cleansed  \
# ...
