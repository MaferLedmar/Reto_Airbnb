# %%
#Importamos Librerias
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Cargamos archivo
df= pd.read_csv('Rio de Janeiro.csv') 
df
# Out:
# C:\Users\mafer\AppData\Local\Temp\ipykernel_95484\452272306.py:2: DtypeWarning: Columns (0,2,9,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('Rio de Janeiro.csv')
#                          id                                      listing_url  \
# 0                53344884.0            https://www.airbnb.com/rooms/53344884
# 1                 7801456.0             https://www.airbnb.com/rooms/7801456
# 2                14333905.0            https://www.airbnb.com/rooms/14333905
# 3                44708736.0            https://www.airbnb.com/rooms/44708736
# 4                35351763.0            https://www.airbnb.com/rooms/35351763
# ...                     ...                                              ...
# 26367  715000000000000000.0  https://www.airbnb.com/rooms/715389590402553923
# 26368  715000000000000000.0  https://www.airbnb.com/rooms/715390471182198472
# ...

# %%
df.astype(('instant_bookable':int)).dtypes
# Out:
#   Input In [7]
#     df.astype(('instant_bookable':int)).dftypes
#                                  ^
# SyntaxError: invalid syntax
